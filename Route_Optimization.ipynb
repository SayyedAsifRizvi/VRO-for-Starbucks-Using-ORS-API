# %% [markdown]
# <a href="https://colab.research.google.com/github/SayyedAsifRizvi/VRO-for-Starbucks-Using-ORS-API/blob/main/Route_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Route Optimization

# %%
pip install openrouteservice
# Out:
# Collecting openrouteservice
#   Downloading openrouteservice-2.3.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.11/dist-packages (from openrouteservice) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.0->openrouteservice) (2025.1.31)
# Downloading openrouteservice-2.3.3-py3-none-any.whl (33 kB)
# Installing collected packages: openrouteservice
# Successfully installed openrouteservice-2.3.3

# %%
import folium
import openrouteservice as ors
import math
import pandas as pd

# %%
dtf = pd.read_csv('data_stores.csv')

# %%
dtf.head()
# Out:
#        Brand  Store Number        Store Name Ownership Type  \
# 0  Starbucks  47370-257954     Meritxell, 96       Licensed
# 1  Starbucks  22331-212325  Ajman Drive Thru       Licensed
# 2  Starbucks  47089-256771         Dana Mall       Licensed
# 3  Starbucks  22126-218024        Twofour 54       Licensed
# 4  Starbucks  17127-178586      Al Ain Tower       Licensed
#
#                     Street Address              City State/Province Country  \
# 0                Av. Meritxell, 96  Andorra la Vella              7      AD
# 1             1 Street 69, Al Jarf             Ajman             AJ      AE
# 2     Sheikh Khalifa Bin Zayed St.             Ajman             AJ      AE
# 3                  Al Salam Street         Abu Dhabi             AZ      AE
# 4  Khaldiya Area, Abu Dhabi Island         Abu Dhabi             AZ      AE
#
#   Postcode Phone Number                 Timezone  Longitude  Latitude
# 0    AD500    376818720  GMT+1:00 Europe/Andorra       1.53     42.51
# 1      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.42
# 2      NaN          NaN     GMT+04:00 Asia/Dubai      55.47     25.39
# 3      NaN          NaN     GMT+04:00 Asia/Dubai      54.38     24.48
# 4      NaN          NaN     GMT+04:00 Asia/Dubai      54.54     24.51

# %%
df_unique_countries = dtf['Country'].unique()
print(df_unique_countries)
# Out:
# ['AD' 'AE' 'AR' 'AT' 'AU' 'AW' 'AZ' 'BE' 'BG' 'BH' 'BN' 'BO' 'BR' 'BS'
#  'CA' 'CH' 'CL' 'CN' 'CO' 'CR' 'CW' 'CY' 'CZ' 'DE' 'DK' 'EG' 'ES' 'FI'
#  'FR' 'GB' 'GR' 'GT' 'HU' 'ID' 'IE' 'IN' 'JO' 'JP' 'KH' 'KR' 'KW' 'KZ'
#  'LB' 'LU' 'MA' 'MC' 'MX' 'MY' 'NL' 'NO' 'NZ' 'OM' 'PA' 'PE' 'PH' 'PL'
#  'PR' 'PT' 'QA' 'RO' 'RU' 'SA' 'SE' 'SG' 'SK' 'SV' 'TH' 'TR' 'TT' 'TW'
#  'US' 'VN' 'ZA']

# %%
df_unique_indian_cities = dtf[dtf['Country'] == 'IN']['City'].unique()
print(df_unique_indian_cities)
# Out:
# ['Hyderabad' 'Delhi' 'Gurgaon' 'New Delhi' 'Bangalore' 'Mumbai'
#  'Navi Mumbai' 'Pune' 'Chennai' 'Noida']

# %%
dfb = dtf[dtf['City']=='Bangalore']
dfb
# Out:
#           Brand  Store Number                 Store Name Ownership Type  \
# 6664  Starbucks  21816-215552   Malleswaram - Orion Mall  Joint Venture
# 6665  Starbucks  23293-229025                   JP Nagar  Joint Venture
# 6666  Starbucks  21965-216488               Mahadevapura  Joint Venture
# 6667  Starbucks  21606-213485                Koramangala  Joint Venture
# 6668  Starbucks  22449-221247                Indiranagar  Joint Venture
# 6669  Starbucks  23150-228269  Malleswaram - Mantri Mall  Joint Venture
# 6670  Starbucks  23148-228268             Sadashiv Nagar  Joint Venture
# 6671  Starbucks  24432-237928                 Whitefield  Joint Venture
# 6672  Starbucks  22445-221246             Benniganahalli  Joint Venture
# 6673  Starbucks  21743-215051              Church Street  Joint Venture
#
#                                          Street Address       City  \
# 6664  Grd Flr Orion Mall, Brigade Gateway, Dr Rajkum...  Bangalore
# 6665  100 feet ring road, K.A.S Officer, KAS Off HBC...  Bangalore
# 6666  Upper Ground Floor, Phoenix Market City,, Whit...  Bangalore
# 6667  Ground Floor, 7th block, Near Forum Mall, Kora...  Bangalore
# 6668  Grd Flr, Samrat Bldg, HAL II Stage, 100 ft Rd,...  Bangalore
# 6669  Upper grd flr,Mantri Mall,Mantri Sq No1, Sampa...  Bangalore
# 6670   403, Ground Floor, 8th Main Road, Sadashiv Nagar  Bangalore
# 6671  Ground floor, Prestige Shantiniketan, Crescent...  Bangalore
# 6672  Ground Floor, RMZ Infinity, The Bay, #3 Old Ma...  Bangalore
# 6673  Ground Floor, Prestige RR Building, 55 and 51/...  Bangalore
#
#      State/Province Country Postcode Phone Number                  Timezone  \
# 6664             KA      IN   560055          NaN  GMT+05:30 Asia/New_Delhi
# 6665             KA      IN   560078          NaN  GMT+05:30 Asia/New_Delhi
# 6666             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 6667             KA      IN   560095          NaN  GMT+05:30 Asia/New_Delhi
# 6668             KA      IN   560038          NaN  GMT+05:30 Asia/New_Delhi
# 6669             KA      IN   560003          NaN  GMT+05:30 Asia/New_Delhi
# 6670             KA      IN   560080          NaN  GMT+05:30 Asia/New_Delhi
# 6671             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 6672             KA      IN   560016          NaN  GMT+05:30 Asia/New_Delhi
# 6673             MH      IN   560001          NaN  GMT+05:30 Asia/New_Delhi
#
#       Longitude  Latitude
# 6664      77.56     13.01
# 6665      77.59     12.91
# 6666      77.70     13.00
# 6667      77.61     12.94
# 6668      77.64     12.97
# 6669      77.57     12.99
# 6670      77.58     13.01
# 6671      77.73     12.99
# 6672      77.66     12.99
# 6673      77.61     12.97

# %%
# We take only Fredericton for this experiement, can use other cities or intercities as well but for now let us proceed
city = 'Bangalore'
dtf=dtf[dtf["City"]==city][ ["City", "Street Address", "Latitude", "Longitude"]].reset_index(drop=True)
dtf=dtf.reset_index().rename(columns={"index":"id", "Latitude":"y", "Longitude":"x"})

print("total", len(dtf))
dtf.head(10)
# Out:
# total 10
#    id       City                                     Street Address      y  \
# 0   0  Bangalore  Grd Flr Orion Mall, Brigade Gateway, Dr Rajkum...  13.01
# 1   1  Bangalore  100 feet ring road, K.A.S Officer, KAS Off HBC...  12.91
# 2   2  Bangalore  Upper Ground Floor, Phoenix Market City,, Whit...  13.00
# 3   3  Bangalore  Ground Floor, 7th block, Near Forum Mall, Kora...  12.94
# 4   4  Bangalore  Grd Flr, Samrat Bldg, HAL II Stage, 100 ft Rd,...  12.97
# 5   5  Bangalore  Upper grd flr,Mantri Mall,Mantri Sq No1, Sampa...  12.99
# 6   6  Bangalore   403, Ground Floor, 8th Main Road, Sadashiv Nagar  13.01
# 7   7  Bangalore  Ground floor, Prestige Shantiniketan, Crescent...  12.99
# 8   8  Bangalore  Ground Floor, RMZ Infinity, The Bay, #3 Old Ma...  12.99
# 9   9  Bangalore  Ground Floor, Prestige RR Building, 55 and 51/...  12.97
#
#        x
# 0  77.56
# 1  77.59
# 2  77.70
# 3  77.61
# 4  77.64
# 5  77.57
# 6  77.58
# 7  77.73
# 8  77.66
# 9  77.61

# %%
# visualize the points on a map
# Fetching coordinates
coords = [[row["x"], row["y"]] for index, row in dtf.iterrows()]

m = folium.Map(location=list(reversed([77.56,	13.01])), tiles="cartodbpositron", zoom_start=14)
for coord in coords:
    folium.Marker(location=list(reversed(coord))).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e6b64483c5711d21fd0499bfe11353c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e6b64483c5711d21fd0499bfe11353c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e6b64483c5711d21fd0499bfe11353c = L.map(
#                 &quot;map_6e6b64483c5711d21fd0499bfe11353c&quot;,
#                 {
#                     center: [13.01, 77.56],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5b13d0151a7873d793c2b21336825f4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5b13d0151a7873d793c2b21336825f4.addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_a688efe7f2c86dcabb566ffcf4f19ad2 = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_60c1c72b4a13e67204f0ee57790e28aa = L.marker(
#                 [12.91, 77.59],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_3932279b4c22dac777cc7109588f08de = L.marker(
#                 [13.0, 77.7],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_aee6ec3c430ee529aa4c92e388b40ea2 = L.marker(
#                 [12.94, 77.61],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_1b4fab7f7fda65d446ac74a33c07edf8 = L.marker(
#                 [12.97, 77.64],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_4de095fad385b84ff9a4a29b936e82cb = L.marker(
#                 [12.99, 77.57],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_eb27b9b0fc1972630f110a5d339cb25f = L.marker(
#                 [13.01, 77.58],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_c3ad38a0e9b6111d59137b0bb4df8809 = L.marker(
#                 [12.99, 77.73],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_e81384c1bf65ddcd79e8585446031c0c = L.marker(
#                 [12.99, 77.66],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
#
#             var marker_491b456f052117355408ea3c755a85d8 = L.marker(
#                 [12.97, 77.61],
#                 {
# }
#             ).addTo(map_6e6b64483c5711d21fd0499bfe11353c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Get Open route service client Id and map the starting point
client = ors.Client(key='5b3ce3597851110001cf62485891a7aec2af4b9cad6544386a470a93')

# Example starting point (you can set it as needed)
vehicle_start = [77.56	,13.01]

m = folium.Map(location=list(reversed([77.56,	13.01])), tiles="cartodbpositron", zoom_start=14)
for coord in coords:
    folium.Marker(location=list(reversed(coord))).add_to(m)

folium.Marker(location=list(reversed(vehicle_start)), icon=folium.Icon(color="red")).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5effd15a564f8fec69089ff51e9fd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5effd15a564f8fec69089ff51e9fd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5effd15a564f8fec69089ff51e9fd1 = L.map(
#                 &quot;map_2e5effd15a564f8fec69089ff51e9fd1&quot;,
#                 {
#                     center: [13.01, 77.56],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_687bfedcb49c07fb7b0963bbc43e8e2b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_687bfedcb49c07fb7b0963bbc43e8e2b.addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_524fbe74dfd6e51b2f8e628b532cd1ca = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_53f333e8af7cf19a20102990b5b884f8 = L.marker(
#                 [12.91, 77.59],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_5679ab65bcf583a86682031bbfb378cd = L.marker(
#                 [13.0, 77.7],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_576b38a2b38d9e3662b3293aa74cfca2 = L.marker(
#                 [12.94, 77.61],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_81dc649745c87770a4b6f452e570a0a7 = L.marker(
#                 [12.97, 77.64],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_4bfff87c5de33d176bfde4ce6010752f = L.marker(
#                 [12.99, 77.57],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_ddd3e7fde79b35035168e17c42f2509c = L.marker(
#                 [13.01, 77.58],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_fa4cb2b18cee8793d5cec4a05509c766 = L.marker(
#                 [12.99, 77.73],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_4b9951492f564e7bc3d65ff4b4a329f9 = L.marker(
#                 [12.99, 77.66],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_f1a1f5cc80a27e46fed24881bea1d2ec = L.marker(
#                 [12.97, 77.61],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_b5e3870a10e38bbc444eef872157fd87 = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var icon_acca85ed96dbc1f21d41fce7fcc457e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_b5e3870a10e38bbc444eef872157fd87.setIcon(icon_acca85ed96dbc1f21d41fce7fcc457e0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We do a simple 2 vehicle optimization with each vehicle being able to take a maximum of 5 tasks.

# %%
# We can use 2 trucks for now, this can be changed accordingly
vehicles = [
    ors.optimization.Vehicle(id=0, profile='driving-car', start=vehicle_start, end=vehicle_start, capacity=[5]),
    ors.optimization.Vehicle(id=1, profile='driving-car', start=vehicle_start, end=vehicle_start, capacity=[5])
    ]
jobs = [ors.optimization.Job(id=index, location=coords, amount=[1]) for index, coords in enumerate(coords)]
optimized = client.optimization(jobs=jobs, vehicles=vehicles, geometry=True)
line_colors = ['green', 'orange']
for route in optimized['routes']:
    folium.PolyLine(locations=[list(reversed(coords)) for coords in ors.convert.decode_polyline(route['geometry'])['coordinates']], color=line_colors[route['vehicle']]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5effd15a564f8fec69089ff51e9fd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5effd15a564f8fec69089ff51e9fd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5effd15a564f8fec69089ff51e9fd1 = L.map(
#                 &quot;map_2e5effd15a564f8fec69089ff51e9fd1&quot;,
#                 {
#                     center: [13.01, 77.56],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_687bfedcb49c07fb7b0963bbc43e8e2b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_687bfedcb49c07fb7b0963bbc43e8e2b.addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_524fbe74dfd6e51b2f8e628b532cd1ca = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_53f333e8af7cf19a20102990b5b884f8 = L.marker(
#                 [12.91, 77.59],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_5679ab65bcf583a86682031bbfb378cd = L.marker(
#                 [13.0, 77.7],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_576b38a2b38d9e3662b3293aa74cfca2 = L.marker(
#                 [12.94, 77.61],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_81dc649745c87770a4b6f452e570a0a7 = L.marker(
#                 [12.97, 77.64],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_4bfff87c5de33d176bfde4ce6010752f = L.marker(
#                 [12.99, 77.57],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_ddd3e7fde79b35035168e17c42f2509c = L.marker(
#                 [13.01, 77.58],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_fa4cb2b18cee8793d5cec4a05509c766 = L.marker(
#                 [12.99, 77.73],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_4b9951492f564e7bc3d65ff4b4a329f9 = L.marker(
#                 [12.99, 77.66],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_f1a1f5cc80a27e46fed24881bea1d2ec = L.marker(
#                 [12.97, 77.61],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var marker_b5e3870a10e38bbc444eef872157fd87 = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#             var icon_acca85ed96dbc1f21d41fce7fcc457e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_b5e3870a10e38bbc444eef872157fd87.setIcon(icon_acca85ed96dbc1f21d41fce7fcc457e0);
#
#
#             tile_layer_687bfedcb49c07fb7b0963bbc43e8e2b.addTo(map_2e5effd15a564f8fec69089ff51e9fd1);
#
#
#                 marker_b5e3870a10e38bbc444eef872157fd87.setIcon(icon_acca85ed96dbc1f21d41fce7fcc457e0);
#
#
#             var poly_line_49f73c293389599ed41c0b71cb502fb9 = L.polyline(
#                 [[13.00985, 77.55949], [13.00973, 77.55953], [13.0094, 77.55963], [13.00912, 77.55971], [13.00882, 77.5598], [13.00851, 77.55989], [13.0082, 77.55999], [13.0079, 77.56008], [13.00763, 77.56016], [13.00737, 77.56022], [13.00647, 77.56052], [13.0054, 77.5609], [13.00443, 77.56125], [13.00402, 77.56142], [13.00289, 77.5621], [13.00252, 77.56232], [13.00223, 77.56248], [13.00195, 77.56265], [13.00078, 77.56331], [13.00036, 77.56352], [13.00016, 77.56362], [12.99905, 77.56424], [12.99813, 77.56495], [12.9967, 77.56603], [12.99635, 77.56623], [12.99607, 77.56631], [12.9957, 77.56634], [12.99486, 77.56637], [12.99448, 77.56639], [12.99415, 77.5664], [12.99379, 77.56641], [12.99346, 77.56642], [12.9934, 77.56774], [12.99337, 77.56836], [12.99338, 77.56843], [12.99339, 77.56879], [12.99324, 77.56936], [12.99327, 77.5696], [12.99328, 77.56982], [12.99332, 77.56989], [12.99335, 77.57036], [12.9934, 77.57106], [12.99342, 77.57149], [12.99346, 77.57197], [12.9935, 77.57281], [12.99368, 77.57356], [12.99391, 77.57393], [12.99382, 77.57395], [12.99376, 77.57397], [12.99303, 77.5741

# %% [markdown]
# ### We now add service durations to our jobs and give each vehicle an 8-hour shift. One vehicle takes 2 jobs, while the other vehicles picks up the remaining 6. There are more options to add restrictions to jobs/vehicles, check out the remaining options at the VROOM API. Note that as the Vroom API changes options may differ slightly from what is available on openrouteservice and implemented in openrouteservice-py

# %%
import folium
import math

# Assuming dtf is your DataFrame and contains 'x' and 'y' columns for coordinates
# Create a sample service time for demonstration (adjust as needed)
service_times = [1, 0.5, 1, 6, 1, 1, 1, 0.25,2,3]  # Example service times in hours

# Fetching coordinates and creating the coords list
coords = [
    { 'location': [row["x"], row["y"]], 'service': service_times[index] * 60 * 60 }
    for index, row in dtf.iterrows()
]

# Initialize the map
m = folium.Map(location=list(reversed([77.56,	13.01])), tiles="cartodbpositron", zoom_start=14)

# Add markers to the map
for job in coords:
    folium.Marker(
        location=list(reversed(job['location'])),
        popup=f"Service time: {job['service'] / 60:.1f} minutes"
    ).add_to(m)

# Define the starting point for vehicles
vehicle_start = [77.56,	13.01]

# Add the vehicle starting point marker
folium.Marker(location=list(reversed(vehicle_start)), icon=folium.Icon(color="red")).add_to(m)

# Example vehicle setup (adjust as needed)
vehicles = [
    ors.optimization.Vehicle(id=0, profile='driving-car', start=vehicle_start, end=vehicle_start, time_window=[0, 8*60*60]),
    ors.optimization.Vehicle(id=1, profile='driving-car', start=vehicle_start, end=vehicle_start, time_window=[0, 8*60*60])
]

# Prepare jobs for optimization
jobs = [ors.optimization.Job(id=index, **job) for index, job in enumerate(coords)]
optimized = client.optimization(jobs=jobs, vehicles=vehicles, geometry=True)

# Prepare a list to store the route information
route_info = []

# Add optimized routes to the map
line_colors = ['green', 'orange', 'blue', 'yellow']
for route in optimized['routes']:
    folium.PolyLine(
        locations=[list(reversed(coords)) for coords in ors.convert.decode_polyline(route['geometry'])['coordinates']],
        color=line_colors[route['vehicle']]
    ).add_to(m)

    for step in route['steps']:
        if step['type'] == 'job':
            folium.Marker(
                location=list(reversed(step['location'])),
                popup=f"Arrival time: {math.floor(step['arrival'] / (60*60))} hours {math.floor((step['arrival'] % (60*60)) / 60)} minutes",
                icon=folium.Icon(color=line_colors[route['vehicle']])
            ).add_to(m)

for route in optimized['routes']:
    vehicle_id = route['vehicle']
    for stop_no, step in enumerate(route['steps']):
        if step['type'] == 'job':
            arrival_time = step['arrival']
            arrival_hours = math.floor(arrival_time / (60 * 60))
            arrival_minutes = math.floor((arrival_time % (60 * 60)) / 60)

            # Append the route information to the list
            route_info.append({
                'Vehicle ID': vehicle_id + 1,
                'X': coords[step['job']]['location'][0],
                'Y': coords[step['job']]['location'][1],
                'Arrival Time': f"{arrival_hours} hours {arrival_minutes} minutes",
                'Stop No': stop_no  # Stop numbers starting from 1
            })


# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_772f27d768a7f8cdd77ec6dc68d99f19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_772f27d768a7f8cdd77ec6dc68d99f19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_772f27d768a7f8cdd77ec6dc68d99f19 = L.map(
#                 &quot;map_772f27d768a7f8cdd77ec6dc68d99f19&quot;,
#                 {
#                     center: [13.01, 77.56],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_990337429a1f50a11abc61d1322ba784 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_990337429a1f50a11abc61d1322ba784.addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#             var marker_02e7bcdc46042c671d7ec425c16c4cc9 = L.marker(
#                 [13.01, 77.56],
#                 {
# }
#             ).addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#         var popup_e0dda7827b7657a06218b976a871894f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d4498b31045b3446d78b4e3500beda6 = $(`&lt;div id=&quot;html_9d4498b31045b3446d78b4e3500beda6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Service time: 60.0 minutes&lt;/div&gt;`)[0];
#                 popup_e0dda7827b7657a06218b976a871894f.setContent(html_9d4498b31045b3446d78b4e3500beda6);
#
#
#
#         marker_02e7bcdc46042c671d7ec425c16c4cc9.bindPopup(popup_e0dda7827b7657a06218b976a871894f)
#         ;
#
#
#
#
#             var marker_b6fe9f99aacce622bf5f5637cf738a18 = L.marker(
#                 [12.91, 77.59],
#                 {
# }
#             ).addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#         var popup_db0f5e8b4d66a05d27ef587d8f354e9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5ac0a466b1932dd4c4cf3c7a5cadc76 = $(`&lt;div id=&quot;html_c5ac0a466b1932dd4c4cf3c7a5cadc76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Service time: 30.0 minutes&lt;/div&gt;`)[0];
#                 popup_db0f5e8b4d66a05d27ef587d8f354e9a.setContent(html_c5ac0a466b1932dd4c4cf3c7a5cadc76);
#
#
#
#         marker_b6fe9f99aacce622bf5f5637cf738a18.bindPopup(popup_db0f5e8b4d66a05d27ef587d8f354e9a)
#         ;
#
#
#
#
#             var marker_bd9dbe99aad0d22acfef5cdd90596662 = L.marker(
#                 [13.0, 77.7],
#                 {
# }
#             ).addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#         var popup_907faf18e768c57a1c20cdcc9d2c4c8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d65ddae830462cc1b91589f170e13ea = $(`&lt;div id=&quot;html_4d65ddae830462cc1b91589f170e13ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Service time: 60.0 minutes&lt;/div&gt;`)[0];
#                 popup_907faf18e768c57a1c20cdcc9d2c4c8f.setContent(html_4d65ddae830462cc1b91589f170e13ea);
#
#
#
#         marker_bd9dbe99aad0d22acfef5cdd90596662.bindPopup(popup_907faf18e768c57a1c20cdcc9d2c4c8f)
#         ;
#
#
#
#
#             var marker_d01b03176aba816858c2b9be3e2c6c02 = L.marker(
#                 [12.94, 77.61],
#                 {
# }
#             ).addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#         var popup_6298647a3562d17215959fd5803af2f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4288929bb7f9a1cabfcdc1b42950c68 = $(`&lt;div id=&quot;html_f4288929bb7f9a1cabfcdc1b42950c68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Service time: 360.0 minutes&lt;/div&gt;`)[0];
#                 popup_6298647a3562d17215959fd5803af2f7.setContent(html_f4288929bb7f9a1cabfcdc1b42950c68);
#
#
#
#         marker_d01b03176aba816858c2b9be3e2c6c02.bindPopup(popup_6298647a3562d17215959fd5803af2f7)
#         ;
#
#
#
#
#             var marker_81ffe40088d37991f6a5ab122373b07f = L.marker(
#                 [12.97, 77.64],
#                 {
# }
#             ).addTo(map_772f27d768a7f8cdd77ec6dc68d99f19);
#
#
#         var popup_969d99f265eebfc386a3d7595a6f0996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fc58dac15f3d505793e665b5b97de52 = $(`&lt;div id=&quot;html_7fc58dac15f3d505793e665b5b97de52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Service time: 60.0 minutes&lt;/div&gt;`)[0];
#                 popup_969d99f265eebfc386a3d7595a6f0996.setContent(html_7fc58dac15f3d505793e665b5b97de52);
#
#
#
#         marker_81ffe40088d37991f6a5ab122373b07f.bindPopup(popup_969d99f265eebfc386a3d7595a6f0996)
#         ;

# %% [markdown]
# ### Now let us print the route details for the drivers

# %%
dfroute = pd.DataFrame(route_info)
dfroute
# Out:
#    Vehicle ID      X      Y        Arrival Time  Stop No
# 0           1  77.58  13.01   0 hours 5 minutes        1
# 1           1  77.70  13.00  1 hours 30 minutes        2
# 2           1  77.73  12.99  2 hours 39 minutes        3
# 3           1  77.66  12.99   3 hours 9 minutes        4
# 4           1  77.64  12.97  5 hours 14 minutes        5
# 5           1  77.59  12.91  6 hours 30 minutes        6
# 6           2  77.61  12.97  0 hours 15 minutes        1
# 7           2  77.57  12.99  3 hours 27 minutes        2
# 8           2  77.56  13.01  4 hours 31 minutes        3

# %%
# Let us merge the two dataframes

# Merge the DataFrames based on X and Y coordinates
merged_df = pd.merge(dfroute, dfb, left_on=['X', 'Y'], right_on=['Longitude', 'Latitude'], how='inner')

merged_df
# Out:
#    Vehicle ID      X      Y        Arrival Time  Stop No      Brand  \
# 0           1  77.58  13.01   0 hours 5 minutes        1  Starbucks
# 1           1  77.70  13.00  1 hours 30 minutes        2  Starbucks
# 2           1  77.73  12.99  2 hours 39 minutes        3  Starbucks
# 3           1  77.66  12.99   3 hours 9 minutes        4  Starbucks
# 4           1  77.64  12.97  5 hours 14 minutes        5  Starbucks
# 5           1  77.59  12.91  6 hours 30 minutes        6  Starbucks
# 6           2  77.61  12.97  0 hours 15 minutes        1  Starbucks
# 7           2  77.57  12.99  3 hours 27 minutes        2  Starbucks
# 8           2  77.56  13.01  4 hours 31 minutes        3  Starbucks
#
#    Store Number                 Store Name Ownership Type  \
# 0  23148-228268             Sadashiv Nagar  Joint Venture
# 1  21965-216488               Mahadevapura  Joint Venture
# 2  24432-237928                 Whitefield  Joint Venture
# 3  22445-221246             Benniganahalli  Joint Venture
# 4  22449-221247                Indiranagar  Joint Venture
# 5  23293-229025                   JP Nagar  Joint Venture
# 6  21743-215051              Church Street  Joint Venture
# 7  23150-228269  Malleswaram - Mantri Mall  Joint Venture
# 8  21816-215552   Malleswaram - Orion Mall  Joint Venture
#
#                                       Street Address       City  \
# 0   403, Ground Floor, 8th Main Road, Sadashiv Nagar  Bangalore
# 1  Upper Ground Floor, Phoenix Market City,, Whit...  Bangalore
# 2  Ground floor, Prestige Shantiniketan, Crescent...  Bangalore
# 3  Ground Floor, RMZ Infinity, The Bay, #3 Old Ma...  Bangalore
# 4  Grd Flr, Samrat Bldg, HAL II Stage, 100 ft Rd,...  Bangalore
# 5  100 feet ring road, K.A.S Officer, KAS Off HBC...  Bangalore
# 6  Ground Floor, Prestige RR Building, 55 and 51/...  Bangalore
# 7  Upper grd flr,Mantri Mall,Mantri Sq No1, Sampa...  Bangalore
# 8  Grd Flr Orion Mall, Brigade Gateway, Dr Rajkum...  Bangalore
#
#   State/Province Country Postcode Phone Number                  Timezone  \
# 0             KA      IN   560080          NaN  GMT+05:30 Asia/New_Delhi
# 1             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 2             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 3             KA      IN   560016          NaN  GMT+05:30 Asia/New_Delhi
# 4             KA      IN   560038          NaN  GMT+05:30 Asia/New_Delhi
# 5             KA      IN   560078          NaN  GMT+05:30 Asia/New_Delhi
# 6             MH      IN   560001          NaN  GMT+05:30 Asia/New_Delhi
# 7             KA      IN   560003          NaN  GMT+05:30 Asia/New_Delhi
# 8             KA      IN   560055          NaN  GMT+05:30 Asia/New_Delhi
#
#    Longitude  Latitude
# 0      77.58     13.01
# 1      77.70     13.00
# 2      77.73     12.99
# 3      77.66     12.99
# 4      77.64     12.97
# 5      77.59     12.91
# 6      77.61     12.97
# 7      77.57     12.99
# 8      77.56     13.01

# %% [markdown]
# ### There seems to be overlap as two locations have same longitudes and latitudes and so we remove either one to enable the route

# %%
# Remove duplicates
merged_df.drop_duplicates(subset=['Vehicle ID', 'X', 'Y'], keep='first', inplace=True)
merged_df
# Out:
#    Vehicle ID      X      Y        Arrival Time  Stop No      Brand  \
# 0           1  77.58  13.01   0 hours 5 minutes        1  Starbucks
# 1           1  77.70  13.00  1 hours 30 minutes        2  Starbucks
# 2           1  77.73  12.99  2 hours 39 minutes        3  Starbucks
# 3           1  77.66  12.99   3 hours 9 minutes        4  Starbucks
# 4           1  77.64  12.97  5 hours 14 minutes        5  Starbucks
# 5           1  77.59  12.91  6 hours 30 minutes        6  Starbucks
# 6           2  77.61  12.97  0 hours 15 minutes        1  Starbucks
# 7           2  77.57  12.99  3 hours 27 minutes        2  Starbucks
# 8           2  77.56  13.01  4 hours 31 minutes        3  Starbucks
#
#    Store Number                 Store Name Ownership Type  \
# 0  23148-228268             Sadashiv Nagar  Joint Venture
# 1  21965-216488               Mahadevapura  Joint Venture
# 2  24432-237928                 Whitefield  Joint Venture
# 3  22445-221246             Benniganahalli  Joint Venture
# 4  22449-221247                Indiranagar  Joint Venture
# 5  23293-229025                   JP Nagar  Joint Venture
# 6  21743-215051              Church Street  Joint Venture
# 7  23150-228269  Malleswaram - Mantri Mall  Joint Venture
# 8  21816-215552   Malleswaram - Orion Mall  Joint Venture
#
#                                       Street Address       City  \
# 0   403, Ground Floor, 8th Main Road, Sadashiv Nagar  Bangalore
# 1  Upper Ground Floor, Phoenix Market City,, Whit...  Bangalore
# 2  Ground floor, Prestige Shantiniketan, Crescent...  Bangalore
# 3  Ground Floor, RMZ Infinity, The Bay, #3 Old Ma...  Bangalore
# 4  Grd Flr, Samrat Bldg, HAL II Stage, 100 ft Rd,...  Bangalore
# 5  100 feet ring road, K.A.S Officer, KAS Off HBC...  Bangalore
# 6  Ground Floor, Prestige RR Building, 55 and 51/...  Bangalore
# 7  Upper grd flr,Mantri Mall,Mantri Sq No1, Sampa...  Bangalore
# 8  Grd Flr Orion Mall, Brigade Gateway, Dr Rajkum...  Bangalore
#
#   State/Province Country Postcode Phone Number                  Timezone  \
# 0             KA      IN   560080          NaN  GMT+05:30 Asia/New_Delhi
# 1             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 2             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 3             KA      IN   560016          NaN  GMT+05:30 Asia/New_Delhi
# 4             KA      IN   560038          NaN  GMT+05:30 Asia/New_Delhi
# 5             KA      IN   560078          NaN  GMT+05:30 Asia/New_Delhi
# 6             MH      IN   560001          NaN  GMT+05:30 Asia/New_Delhi
# 7             KA      IN   560003          NaN  GMT+05:30 Asia/New_Delhi
# 8             KA      IN   560055          NaN  GMT+05:30 Asia/New_Delhi
#
#    Longitude  Latitude
# 0      77.58     13.01
# 1      77.70     13.00
# 2      77.73     12.99
# 3      77.66     12.99
# 4      77.64     12.97
# 5      77.59     12.91
# 6      77.61     12.97
# 7      77.57     12.99
# 8      77.56     13.01

# %%
merged_df.drop(['X','Y'],axis=1, inplace=True)
merged_df
# Out:
#    Vehicle ID        Arrival Time  Stop No      Brand  Store Number  \
# 0           1   0 hours 5 minutes        1  Starbucks  23148-228268
# 1           1  1 hours 30 minutes        2  Starbucks  21965-216488
# 2           1  2 hours 39 minutes        3  Starbucks  24432-237928
# 3           1   3 hours 9 minutes        4  Starbucks  22445-221246
# 4           1  5 hours 14 minutes        5  Starbucks  22449-221247
# 5           1  6 hours 30 minutes        6  Starbucks  23293-229025
# 6           2  0 hours 15 minutes        1  Starbucks  21743-215051
# 7           2  3 hours 27 minutes        2  Starbucks  23150-228269
# 8           2  4 hours 31 minutes        3  Starbucks  21816-215552
#
#                   Store Name Ownership Type  \
# 0             Sadashiv Nagar  Joint Venture
# 1               Mahadevapura  Joint Venture
# 2                 Whitefield  Joint Venture
# 3             Benniganahalli  Joint Venture
# 4                Indiranagar  Joint Venture
# 5                   JP Nagar  Joint Venture
# 6              Church Street  Joint Venture
# 7  Malleswaram - Mantri Mall  Joint Venture
# 8   Malleswaram - Orion Mall  Joint Venture
#
#                                       Street Address       City  \
# 0   403, Ground Floor, 8th Main Road, Sadashiv Nagar  Bangalore
# 1  Upper Ground Floor, Phoenix Market City,, Whit...  Bangalore
# 2  Ground floor, Prestige Shantiniketan, Crescent...  Bangalore
# 3  Ground Floor, RMZ Infinity, The Bay, #3 Old Ma...  Bangalore
# 4  Grd Flr, Samrat Bldg, HAL II Stage, 100 ft Rd,...  Bangalore
# 5  100 feet ring road, K.A.S Officer, KAS Off HBC...  Bangalore
# 6  Ground Floor, Prestige RR Building, 55 and 51/...  Bangalore
# 7  Upper grd flr,Mantri Mall,Mantri Sq No1, Sampa...  Bangalore
# 8  Grd Flr Orion Mall, Brigade Gateway, Dr Rajkum...  Bangalore
#
#   State/Province Country Postcode Phone Number                  Timezone  \
# 0             KA      IN   560080          NaN  GMT+05:30 Asia/New_Delhi
# 1             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 2             KA      IN   560048          NaN  GMT+05:30 Asia/New_Delhi
# 3             KA      IN   560016          NaN  GMT+05:30 Asia/New_Delhi
# 4             KA      IN   560038          NaN  GMT+05:30 Asia/New_Delhi
# 5             KA      IN   560078          NaN  GMT+05:30 Asia/New_Delhi
# 6             MH      IN   560001          NaN  GMT+05:30 Asia/New_Delhi
# 7             KA      IN   560003          NaN  GMT+05:30 Asia/New_Delhi
# 8             KA      IN   560055          NaN  GMT+05:30 Asia/New_Delhi
#
#    Longitude  Latitude
# 0      77.58     13.01
# 1      77.70     13.00
# 2      77.73     12.99
# 3      77.66     12.99
# 4      77.64     12.97
# 5      77.59     12.91
# 6      77.61     12.97
# 7      77.57     12.99
# 8      77.56     13.01

# %%
# For vehicle 1 and vehicle 2 to a excel

df1= merged_df[merged_df['Vehicle ID']==1]
df1.to_excel('route_details_for_vehicle1.xlsx',index=False)
df2= merged_df[merged_df['Vehicle ID']==2]
df1.to_excel('route_details_for_vehicle2.xlsx',index=False)
